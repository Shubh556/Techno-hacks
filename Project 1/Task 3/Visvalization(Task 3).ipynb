# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.shape
# Out:
# (150, 6)

# %%
plt.figure(figsize=(15,7))
sns.histplot(df["SepalLengthCm"], label="Sepal Length")
sns.histplot(df["SepalWidthCm"], label="Sepal Width")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(df["PetalLengthCm"], label="Petal Length",color="red")
sns.histplot(df["PetalWidthCm"], label="Petal Width",color="green")
plt.legend()
plt.show()

# %%
sns.boxplot(data=df[["PetalLengthCm","PetalWidthCm","SepalWidthCm","SepalLengthCm"]])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df["SepalWidthCm"])
# Out:
# <Axes: >

# %% [markdown]
# Removing Outliers from the data

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
IQR=3.30-2.80
IQR
# Out:
# 0.5

# %%
lower_limit = 2.80-1.5*IQR
upper_limit = 3.30 +1.5*IQR

# %%
lower_limit,upper_limit
# Out:
# (2.05, 4.05)

# %%
df[(df.SepalWidthCm<lower_limit)|(df.SepalWidthCm>upper_limit)]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 15  16            5.7           4.4            1.5           0.4
# 32  33            5.2           4.1            1.5           0.1
# 33  34            5.5           4.2            1.4           0.2
# 60  61            5.0           2.0            3.5           1.0
#
#             Species
# 15      Iris-setosa
# 32      Iris-setosa
# 33      Iris-setosa
# 60  Iris-versicolor

# %%
new_df_with_no_outliers=df[(df.SepalWidthCm>lower_limit)&(df.SepalWidthCm<upper_limit)]
new_df_with_no_outliers
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.boxplot(new_df_with_no_outliers[["SepalWidthCm","SepalLengthCm","PetalLengthCm","PetalWidthCm"]])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,7))
sns.histplot(new_df_with_no_outliers["PetalLengthCm"], label="Petal Length",color="red")
sns.histplot(new_df_with_no_outliers["PetalWidthCm"], label="Petal Width",color="green")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(new_df_with_no_outliers["SepalLengthCm"], label="Sepal Length")
sns.histplot(new_df_with_no_outliers["SepalWidthCm"], label="Sepal Width")
plt.legend()
plt.show()
